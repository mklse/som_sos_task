# %%
# Read data from Java SOMToolbox
from SOMToolBox_Parse import SOMToolBox_Parse
idata   = SOMToolBox_Parse("datasets\\iris\\iris.vec").read_weight_file()
weights = SOMToolBox_Parse("datasets\\iris\\iris.wgt.gz").read_weight_file()
classes = SOMToolBox_Parse("datasets\\iris\\iris.cls").read_weight_file()

# %%
# !pip install import-ipynb
import import_ipynb
import coding_assignment
# Out:
# WARNING: Ignoring invalid distribution -cipy (c:\users\morit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\morit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\morit\anaconda3\lib\site-packages)
# ...
# Sample keys in weights: ['type', 'xdim', 'ydim', 'vec_dim', 'arr']
# {'type': 'som', 'xdim': 10, 'ydim': 10, 'vec_dim': 4, 'arr': array([[5.3410615 , 2.49928854, 4.20200498, 1.40913253],
#        [5.08971693, 2.55015807, 4.46014385, 1.60807605],
#        [5.53853625, 2.68629902, 4.80619443, 1.80991903],
#        [5.73177201, 2.67858746, 5.0168371 , 1.95372459],
#        [5.91573778, 2.89064894, 5.10027157, 2.20001784],
#        [6.31026941, 3.26484043, 5.34274753, 2.28351449],
#        [6.36966232, 3.31653036, 5.71675321, 2.4094243 ],
#        [6.75097948, 3.21307518, 5.71330659, 2.33162275],
#        [7.17943861, 3.39373312, 6.09536849, 2.3516351 ],
#        [7.71452104, 3.1657159 , 6.66306422, 2.12873892],
# ...

# %%
# Visualization by PySOMVis
from pysomvis import PySOMVis

vis = PySOMVis(weights=weights['arr'], m=weights['ydim'],n=weights['xdim'],
                dimension=weights['vec_dim'], input_data=idata['arr'],
                classes=classes['arr'][:,1], component_names=classes['classes_names'])
vis._mainview
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4845c3e6-751b-4590-8630-38d2e48c23a5'>
#   <div id="dbb73f24-9f59-4ce0-be05-b355b6dbf31d" data-root-id="4845c3e6-751b-4590-8630-38d2e48c23a5" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Use any library for training SOM map (e.x. MiniSOM, SOMOClu, SOMpy, PopSOM etc.)
from pysomvis import PySOMVis
from minisom import MiniSom    

som = MiniSom(10, 10, 4)
som.train(idata['arr'], 10000)

vis = PySOMVis(weights=som._weights, input_data=idata['arr'])
vis._mainview
# Out:
# Column
#     [0] Column
#         [0] Column
#             [0] Row(margin=(5, 10), width=700)
#                 [0] StaticText(value='<b></b>')
#                 [1] Select(options=OrderedDict([('Component P...]), value=0)
#                 [2] Select(options=OrderedDict([('PiYG', ...]), value='jet')
#                 [3] Button(name='↶')
#                 [4] Button(name='↷')
#                 [5] Button(name='↔')
#                 [6] Button(name='↕')
#                 [7] Checkbox(name='interpolation')
#         [1] Row
#             [0] Column
#                 [0] HoloViews(DynamicMap, height=500, sizing_mode='fixed', width=500)
#             [1] Row
#                 [0] Column
#                     [0] Column(margin=(5, 10), name='Component Planes')
#                         [0] StaticText(value='<b>Component Planes</b>')
#                         [1] IntSlider(end=3, name='Component')
#                     [1] Str(str)
#     [1] Column
#         [0] Row()

# %%
chainlink_data   = SOMToolBox_Parse("datasets\\chainlink\\chainlink.vec").read_weight_file()
clusters_data   = SOMToolBox_Parse("datasets\\10clusters\\10clusters.vec").read_weight_file()


small_som_chainlink = MiniSom(10, 10, 3)
#small_som_chainlink.train(chainlink_data['arr'], 10000)

small_som_clusters = MiniSom(10, 10, 10)
#small_som_clusters.train(clusters_data['arr'], 10000)

large_som_chainlink = MiniSom(100, 60, 3)
#large_som_chainlink.train(chainlink_data['arr'], 10000)

large_som_clusters = MiniSom(100, 60, 10)
large_som_clusters.train(clusters_data['arr'], 10000)

small_som_clusters_weights = small_som_clusters.get_weights()
print(small_som_clusters_weights[-1])
coding_assignment.calculate_complete_topographic_product(small_som_clusters_weights[-1], k_max=3)
# Out:
# [[ 2.55625306e-01 -2.27369334e-01 -4.97763900e-01 -3.48259060e-01
#   -3.53108633e-01  4.58985381e-01 -2.07636646e-01 -3.53192221e-01
#    1.01428959e-01 -2.01686260e-02]
#  [-2.60265673e-01 -3.24200985e-01 -2.70122765e-01 -2.95324500e-01
#    2.82590110e-02 -2.94023890e-01  3.37053280e-01 -1.98897614e-01
#    4.65202907e-01  4.58415852e-01]
#  [-1.24087562e-01  5.53546656e-01 -3.53921355e-01  4.46814817e-02
#   -3.74255358e-02  3.91941385e-02 -4.52477750e-01  4.95332999e-01
#   -2.38395609e-01  2.02660811e-01]
#  [ 1.46289069e-01  5.60660719e-01  5.32985766e-01 -7.00068291e-02
#   -2.78209982e-01 -4.20642456e-01 -2.70883716e-02  1.93559766e-02
#   -2.41301991e-01 -2.48210253e-01]
#  [-2.34876417e-01  4.32387028e-01 -4.44652978e-01  4.30686816e-02
#    2.52005270e-01  1.18152631e-01 -2.73003474e-01 -3.05860614e-01
#   -3.76077621e-01  4.13908995e-01]
#  [-4.13327472e-01  2.90707009e-01 -4.07567439e-02 -3.81008870e-01
# ...
